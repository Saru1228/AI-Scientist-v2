# %%
import os, getpass
os.environ["OPENAI_API_KEY"] = getpass.getpass("🔑 请输入你的 OpenAI API Key: ")

# %%
import os; print(os.getenv("OPENAI_API_KEY")[:8] + "…")
# Out:
#  sk-proj…

# %%
import os

# %%
os.makedirs("ai_scientist/my_experiment/ideas", exist_ok=True)

# %%
# !python launch_scientist_bfts.py \
  --load_ideas ai_scientist/my_experiment/ideas/My_idea.json \
  --load_code ai_scientist/my_experiment/code/language_modeling \
  --add_dataset_ref \
  --model_writeup  gpt-4o-mini-2024-07-18 \
  --model_citation gpt-4o-mini-2024-07-18 \
  --model_review   gpt-4o-mini-2024-07-18 \
  --model_agg_plots gpt-4o-mini-2024-07-18 \
  --num_cite_rounds 5
# Out:
# Traceback (most recent call last):
#   File "c:\Users\Saru\Desktop\在日本\Sakana\task5\AI-Scientist-v2\launch_scientist_bfts.py", line 10, in <module>
#     from ai_scientist.llm import create_client
#   File "c:\Users\Saru\Desktop\在日本\Sakana\task5\AI-Scientist-v2\ai_scientist\llm.py", line 7, in <module>
#     import anthropic
# ModuleNotFoundError: No module named 'anthropic'
